# %%
import pandas as pd
import numpy as np
import random
import json
import re
import os

from datetime import datetime

# %% [markdown]
# # IDENTIFY ALL JSON FILES

# %%
files = []

for f in os.listdir():
    if re.findall('.json', f) != []:
        files.append(f)
    else:
        pass

files
# Out:
# ['brands.json', 'receipts.json', 'users.json']

# %% [markdown]
# # PARSE brands.json FILE

# %%
# READ + VIEW DATASTRUCTURE
df_brands = pd.read_json('brands.json', lines=True)
df_brands.head(3)
# Out:
#                                     _id       barcode   category categoryCode  \
# 0  {'$oid': '601ac115be37ce2ead437551'}  511111019862     Baking       BAKING
# 1  {'$oid': '601c5460be37ce2ead43755f'}  511111519928  Beverages    BEVERAGES
# 2  {'$oid': '601ac142be37ce2ead43755d'}  511111819905     Baking       BAKING
#
#                                                  cpg  \
# 0  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
#
#                         name  topBrand                      brandCode
# 0  test brand @1612366101024       0.0                            NaN
# 1                  Starbucks       0.0                      STARBUCKS
# 2  test brand @1612366146176       0.0  TEST BRANDCODE @1612366146176

# %%
# STRIP OUT NESTED DICTIONARY VALUES
df_brands['_id'] = df_brands['_id'].apply(lambda i: i['$oid'])
df_brands['cpg_id'] = df_brands['cpg'].apply(lambda i: i['$id']['$oid'])
df_brands['ref'] = df_brands['cpg'].apply(lambda i: i['$ref'])

# %%
# FILTER OUT COLS
cols = df_brands.columns.tolist()
cols.remove('cpg')
df_brands = df_brands[cols]

# %%
# VIEW DATASTRUCTURE
df_brands.head(3)
# Out:
#                         _id       barcode   category categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862     Baking       BAKING
# 1  601c5460be37ce2ead43755f  511111519928  Beverages    BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905     Baking       BAKING
#
#                         name  topBrand                      brandCode  \
# 0  test brand @1612366101024       0.0                            NaN
# 1                  Starbucks       0.0                      STARBUCKS
# 2  test brand @1612366146176       0.0  TEST BRANDCODE @1612366146176
#
#                      cpg_id   ref
# 0  601ac114be37ce2ead437550  Cogs
# 1  5332f5fbe4b03c9a25efd0ba  Cogs
# 2  601ac142be37ce2ead437559  Cogs

# %% [markdown]
# # PARSE receipts.json FILE

# %%
# READ + VIEW DATASTRUCTURE
df_receipts = pd.read_json('receipts.json', lines=True)
df_receipts.head(3)
# Out:
#                                     _id  bonusPointsEarned  \
# 0  {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1  {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2  {'$oid': '5ff1e1f10a720f052300057a'}                5.0
#
#                              bonusPointsEarnedReason  \
# 0  Receipt number 2 completed, bonus point schedu...
# 1  Receipt number 5 completed, bonus point schedu...
# 2                         All-receipts receipt bonus
#
#                  createDate               dateScanned  \
# 0  {'$date': 1609687531000}  {'$date': 1609687531000}
# 1  {'$date': 1609687483000}  {'$date': 1609687483000}
# 2  {'$date': 1609687537000}  {'$date': 1609687537000}
#
#                finishedDate                modifyDate  \
# 0  {'$date': 1609687531000}  {'$date': 1609687536000}
# 1  {'$date': 1609687483000}  {'$date': 1609687488000}
# 2                       NaN  {'$date': 1609687542000}
#
#           pointsAwardedDate  pointsEarned              purchaseDate  \
# 0  {'$date': 1609687531000}         500.0  {'$date': 1609632000000}
# 1  {'$date': 1609687483000}         150.0  {'$date': 1609601083000}
# 2                       NaN           5.0  {'$date': 1609632000000}
#
#    purchasedItemCount                             rewardsReceiptItemList  \
# 0                 5.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 1                 2.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 2                 1.0  [{'needsFetchReview': False, 'partnerItemId': ...
#
#   rewardsReceiptStatus  totalSpent                    userId
# 0             FINISHED        26.0  5ff1e1eacfcf6c399c274ae6
# 1             FINISHED        11.0  5ff1e194b6a9d73a3a9f1052
# 2             REJECTED        10.0  5ff1e1f1cfcf6c399c274b0b

# %%
# STRIP OUT NESTED DICTIONARY VALUES
df_receipts['_id'] = df_receipts['_id'].apply(lambda i: i['$oid'])

for c in [c for c in df_receipts.columns if re.findall('date', c.lower())!=[]]:
    df_receipts[c] = df_receipts[c].apply(lambda i: datetime.fromtimestamp(i['$date'] // 1000) if str(i) != str(np.nan) else i)

# %%
# GET LIST OF ALL DICTIONARY KEYS WITHIN rewardsReceiptItemList COL

keys = []

for i in df_receipts[~df_receipts.rewardsReceiptItemList.isnull()].reset_index(drop=True).rewardsReceiptItemList:
    keys.extend(i[0].keys())
    
keys = list(set(keys))

# %%
# CREATE SUBTABLE FOR rewardsReceiptItemList VALUES
df_receipts_sbtbl = pd.DataFrame(columns=['receipt_id']+keys, dtype='object')

# %%
# ASSIGN receipts.json '_id' AS DICTIONARY VALUE FOR rewardsReceiptItemList COL VALUES
for i in list(range(len(df_receipts))):
    if isinstance(df_receipts.rewardsReceiptItemList[i], list):
        df_receipts.rewardsReceiptItemList[i][0]['receipt_id'] = df_receipts._id[i]
    elif str(df_receipts.rewardsReceiptItemList[i]) == str(np.nan):
        df_receipts.rewardsReceiptItemList[i] = [{'receipt_id': df_receipts._id[i]}]
    else:
        print(df_receipts.rewardsReceiptItemList[i])
# Out:
# C:\Users\teddy\Envs\main_env\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# STRIP OUT NESTED DICTIONARY VALUES for rewardsReceiptItemList COL
for i in list(range(len(df_receipts))):
    for k in (keys + ['receipt_id']):
        try:
            df_receipts.rewardsReceiptItemList[i][0][k] =  [df_receipts.rewardsReceiptItemList[i][0][k]]
        except:
            pass
        
    df_hold = pd.DataFrame.from_dict(df_receipts.rewardsReceiptItemList[i][0])
    df_receipts_sbtbl = df_receipts_sbtbl.append(df_hold, sort=False).reset_index(drop=True)

# %%
# FILTER OUT COLS
cols = df_receipts.columns.tolist()
cols.remove('rewardsReceiptItemList')
df_receipts = df_receipts[cols]

# %%
# VIEW DATASTRUCTURE
df_receipts.head(3)
# Out:
#                         _id  bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
#
#                              bonusPointsEarnedReason          createDate  \
# 0  Receipt number 2 completed, bonus point schedu... 2021-01-03 10:25:31
# 1  Receipt number 5 completed, bonus point schedu... 2021-01-03 10:24:43
# 2                         All-receipts receipt bonus 2021-01-03 10:25:37
#
#           dateScanned        finishedDate          modifyDate  \
# 0 2021-01-03 10:25:31 2021-01-03 10:25:31 2021-01-03 10:25:36
# 1 2021-01-03 10:24:43 2021-01-03 10:24:43 2021-01-03 10:24:48
# 2 2021-01-03 10:25:37                 NaT 2021-01-03 10:25:42
#
#     pointsAwardedDate  pointsEarned        purchaseDate  purchasedItemCount  \
# 0 2021-01-03 10:25:31         500.0 2021-01-02 19:00:00                 5.0
# 1 2021-01-03 10:24:43         150.0 2021-01-02 10:24:43                 2.0
# 2                 NaT           5.0 2021-01-02 19:00:00                 1.0
#
#   rewardsReceiptStatus  totalSpent                    userId
# 0             FINISHED        26.0  5ff1e1eacfcf6c399c274ae6
# 1             FINISHED        11.0  5ff1e194b6a9d73a3a9f1052
# 2             REJECTED        10.0  5ff1e1f1cfcf6c399c274b0b

# %% [markdown]
# # PARSE users .json FILE

# %%
# READ + VIEW DATASTRUCTURE
df_users = pd.read_json('users.json', lines=True)
df_users.head(3)
# Out:
#                                     _id  active               createdDate  \
# 0  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 1  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 2  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
#
#                   lastLogin      role signUpSource state
# 0  {'$date': 1609687537858}  consumer        Email    WI
# 1  {'$date': 1609687537858}  consumer        Email    WI
# 2  {'$date': 1609687537858}  consumer        Email    WI

# %%
# STRIP OUT NESTED DICTIONARY VALUES
df_users['_id'] = df_users['_id'].apply(lambda i: i['$oid'])
df_users['createdDate'] = df_users['createdDate'].apply(lambda i: datetime.fromtimestamp(i['$date'] // 1000) if str(i) != str(np.nan) else i)
df_users['lastLogin'] = df_users['lastLogin'].apply(lambda i: datetime.fromtimestamp(i['$date'] // 1000) if str(i) != str(np.nan) else i)

# %%
# REMOVE DUP '_id' RECORDS ('createdDate' takes precedence)

# %%
df_users = df_users.sort_values(by=['createdDate', '_id'], ascending=True).reset_index(drop=True)

# %%
df_users = df_users.drop_duplicates(subset='_id', keep='first')

# %%
# VIEW DATASTRUCTURE
df_users.head(3)
# Out:
#                          _id  active         createdDate           lastLogin  \
# 0   54943462e4b07e684157a532    True 2014-12-19 09:21:22 2021-03-05 11:52:23
# 20  55308179e4b0eabd8f99caa2    True 2015-04-16 23:43:53 2018-05-07 13:23:40
# 21  5964eb07e4b03efd0c0f267b    True 2017-07-11 11:13:11 2021-03-04 14:07:49
#
#            role signUpSource state
# 0   fetch-staff          NaN   NaN
# 20     consumer          NaN    WI
# 21  fetch-staff          NaN    IL

# %% [markdown]
# # REVIEW FINAL PARSED DATAFRAMES

# %%
[var for var in dir() if (isinstance(eval(var), pd.core.frame.DataFrame) and re.findall('df', var))]
# Out:
# ['df_brands', 'df_hold', 'df_receipts', 'df_receipts_sbtbl', 'df_users']

# %%
df_brands.head(3)
# Out:
#                         _id       barcode   category categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862     Baking       BAKING
# 1  601c5460be37ce2ead43755f  511111519928  Beverages    BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905     Baking       BAKING
#
#                         name  topBrand                      brandCode  \
# 0  test brand @1612366101024       0.0                            NaN
# 1                  Starbucks       0.0                      STARBUCKS
# 2  test brand @1612366146176       0.0  TEST BRANDCODE @1612366146176
#
#                      cpg_id   ref
# 0  601ac114be37ce2ead437550  Cogs
# 1  5332f5fbe4b03c9a25efd0ba  Cogs
# 2  601ac142be37ce2ead437559  Cogs

# %%
df_receipts.head(3)
# Out:
#                         _id  bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
#
#                              bonusPointsEarnedReason          createDate  \
# 0  Receipt number 2 completed, bonus point schedu... 2021-01-03 10:25:31
# 1  Receipt number 5 completed, bonus point schedu... 2021-01-03 10:24:43
# 2                         All-receipts receipt bonus 2021-01-03 10:25:37
#
#           dateScanned        finishedDate          modifyDate  \
# 0 2021-01-03 10:25:31 2021-01-03 10:25:31 2021-01-03 10:25:36
# 1 2021-01-03 10:24:43 2021-01-03 10:24:43 2021-01-03 10:24:48
# 2 2021-01-03 10:25:37                 NaT 2021-01-03 10:25:42
#
#     pointsAwardedDate  pointsEarned        purchaseDate  purchasedItemCount  \
# 0 2021-01-03 10:25:31         500.0 2021-01-02 19:00:00                 5.0
# 1 2021-01-03 10:24:43         150.0 2021-01-02 10:24:43                 2.0
# 2                 NaT           5.0 2021-01-02 19:00:00                 1.0
#
#   rewardsReceiptStatus  totalSpent                    userId
# 0             FINISHED        26.0  5ff1e1eacfcf6c399c274ae6
# 1             FINISHED        11.0  5ff1e194b6a9d73a3a9f1052
# 2             REJECTED        10.0  5ff1e1f1cfcf6c399c274b0b

# %%
df_receipts_sbtbl.head(3)
# Out:
#                  receipt_id originalMetaBriteQuantityPurchased brandCode  \
# 0  5ff1e1eb0a720f0523000575                                NaN       NaN
# 1  5ff1e1bb0a720f052300056b                                NaN       NaN
# 2  5ff1e1f10a720f052300057a                                NaN       NaN
#
#   partnerItemId barcode itemPrice preventTargetGapPoints  \
# 0             1    4011     26.00                   True
# 1             1    4011         1                    NaN
# 2             1     NaN       NaN                   True
#
#   originalReceiptItemText needsFetchReviewReason itemNumber  ...  \
# 0                     NaN                    NaN        NaN  ...
# 1                     NaN                    NaN        NaN  ...
# 2                     NaN                    NaN        NaN  ...
#
#   metabriteCampaignId userFlaggedPrice targetPrice  \
# 0                 NaN            26.00         NaN
# 1                 NaN              NaN         NaN
# 2                 NaN            26.00         NaN
#
#   originalMetaBriteDescription competitiveProduct finalPrice  \
# 0                          NaN                NaN      26.00
# 1                          NaN                NaN          1
# 2                          NaN                NaN        NaN
#
#   quantityPurchased originalMetaBriteBarcode rewardsProductPartnerId deleted
# 0                 5                      NaN                     NaN     NaN
# 1                 1                      NaN                     NaN     NaN
# 2               NaN                      NaN                     NaN     NaN
#
# [3 rows x 33 columns]

# %%
df_users.head(3)
# Out:
#                          _id  active         createdDate           lastLogin  \
# 0   54943462e4b07e684157a532    True 2014-12-19 09:21:22 2021-03-05 11:52:23
# 20  55308179e4b0eabd8f99caa2    True 2015-04-16 23:43:53 2018-05-07 13:23:40
# 21  5964eb07e4b03efd0c0f267b    True 2017-07-11 11:13:11 2021-03-04 14:07:49
#
#            role signUpSource state
# 0   fetch-staff          NaN   NaN
# 20     consumer          NaN    WI
# 21  fetch-staff          NaN    IL

# %% [markdown]
# # WRITE DATAFRAMES TO CSV

# %%
if not os.path.exists('outputs'):
    os.makedirs('outputs')

# %%
df_brands.to_csv('./outputs/brands.csv', index=False)

# %%
df_receipts.to_csv('./outputs/receipts.csv', index=False)

# %%
df_receipts_sbtbl.to_csv('./outputs/receipts_v.csv', index=False)

# %%
df_users.to_csv('./outputs/users.csv', index=False)
